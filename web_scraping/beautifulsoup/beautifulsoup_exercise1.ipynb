# %%
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Write a python program to display all the header tags from wikipedia.org.

# %%
def getHeaders(url):
    request = requests.get(url)
    
    soup = BeautifulSoup(request.text, 'lxml')
    header_tags=set(re.compile(pattern=r'<h\d').findall(request.text))
    header_tags=[re.compile(pattern='h\d').findall(header)[0] for header in header_tags]
    headers={}
    for header_tag in header_tags:
        headers[header_tag]=[]
        for tag in soup.find_all(header_tag):
            headers[tag.name].append(tag.text.strip())
        if len(headers[header_tag])==0:
            headers.pop(header_tag)
    return headers

url='https://www.wikipedia.org/'
getHeaders(url)
# Out:
# {'h2': ['1,000,000+\n\n\narticles',
#   '100,000+\n\n\narticles',
#   '10,000+\n\n\narticles',
#   '1,000+\n\n\narticles',
#   '100+\n\n\narticles'],
#  'h1': ['Wikipedia\n\nThe Free Encyclopedia']}

# %% [markdown]
# ## Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release) and make data frame.

# %%
def getTop100IMDBMovies(url, http_headers):
    html_text = requests.get(url, headers=http_headers).text

    soup = BeautifulSoup(html_text, 'lxml')
    p=re.compile(r'^\d+\..+')
    names=[p.search(name.text).group() for name in soup.find_all('h3', class_='ipc-title__text') if p.search(name.text) is not None][:100]
    p=re.compile(r'\s.+')
    names=[p.search(name).group().strip() for name in names]

    ratings=soup.find_all('span', class_='sc-b0691f29-1 grHDBY')[:100]
    p=re.compile('\d+\.\d+')
    audiance_ratings=[float(p.search(rating.text).group()) for rating in ratings]

    other_details=soup.find_all('div', class_='sc-b0691f29-7 hrgukm cli-title-metadata')[:100]

    years=[]
    runtimes=[]
    rated_labels=[]

    for other_detail in other_details:
        details=other_detail.findAll('span', class_='sc-b0691f29-8 ilsLEX cli-title-metadata-item')
        years.append(int(details[0].text))
        runtimes.append(details[1].text)
        rated_labels.append(details[2].text)

    return pd.DataFrame({
        'Name':names,
        'Audiance_ratings':audiance_ratings,
        'Year_of_release':years,
        'Runtime':runtimes,
        'Rated':rated_labels
    })

http_headers={
    'USER-AGENT':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36 Edg/122.0.0.0'
}
url="https://www.imdb.com/chart/top/?ref_=nv_mv_250&sort=user_rating%2Cdesc"

getTop100IMDBMovies(url, http_headers)
# Out:
#                         Name  Audiance_ratings  Year_of_release Runtime  Rated
# 0   The Shawshank Redemption               9.3             1994  2h 22m  MA15+
# 1              The Godfather               9.2             1972  2h 55m      R
# 2            The Dark Knight               9.0             2008  2h 32m      M
# 3                  12th Fail               9.0             2023  2h 27m     PG
# 4           Schindler's List               9.0             1993  3h 15m      M
# ..                       ...               ...              ...     ...    ...
# 95        A Clockwork Orange               8.3             1971  2h 16m      R
# 96                  Scarface               8.3             1983  2h 50m      R
# 97         Full Metal Jacket               8.3             1987  1h 56m      R
# 98                Braveheart               8.3             1995  2h 58m  MA15+
# 99            Reservoir Dogs               8.3             1992  1h 39m   R18+
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Write a python program to scrape mentioned details from dineout.co.in : i) Restaurant name ii) Cuisine iii) Location iv) Ratings v) Image URL.

# %%
def extract_resturant_details(url):
    html_text=requests.get(url).text
    soup=BeautifulSoup(html_text, 'lxml')

    resturant_details_divs=soup.findAll('div', class_='restnt-main-wrap clearfix')

    resturant_details={
        'name':[],
        'cuisine':[],
        'location':[],
        'rating':[],
        'image_url':[]
    }

    for resturant_details_div in resturant_details_divs:
        image_url=resturant_details_div.find('img', class_='no-img')['data-src']
        resturant_details['image_url'].append(image_url)

        name=resturant_details_div.find('div', class_='restnt-info cursor').a.text
        resturant_details['name'].append(name)

        locations=resturant_details_div.find('div', class_='restnt-loc ellipsis').findAll('a')
        full_location=''
        for location in locations:
            full_location+=location.text+', '
        full_location=full_location.strip()[:-1]
        resturant_details['location'].append(full_location)

        cuisines=resturant_details_div.find('span', class_='double-line-ellipsis').findAll('a')
        full_cuisine=''
        for cuisine in cuisines:
            full_cuisine+=cuisine.text+', '
        full_cuisine=full_cuisine.strip()[:-1]
        resturant_details['cuisine'].append(full_cuisine)

        rating=float(resturant_details_div.find('div', class_='img-wrap').findAll('div')[-1].text)
        resturant_details['rating'].append(rating)
    return resturant_details

url='https://www.dineout.co.in/kolkata-restaurants/welcome-back?city_name=kolkata&limit=100&start=0&cityId=6&listing=1&showAvailableTicket=0&sortby=ratingDESC&tag%5B%5D=Welcome%20Back&tag%5B%5D=Welcome%20Back&p=30'
extract_resturant_details(url)
# Out:
# {'name': ['Blue Nile Lounge',
#   'The Burger Factory',
#   'Eatelicious',
#   'Wow! Momo',
#   'Loca Kitchen & Lounge',
#   'Privy Ultra Lounge',
#   'Subway',
#   'Ego Retro Lounge',
#   'Ocean Grill',
#   'Den',
#   'Ecstasea',
#   'Buddha Bites',
#   'Soul Kitchen',
#   'Bawarchi Family Restaurant',
#   'Jadu Kadai',
#   'Subway',
#   'Wow! Momo',
#   'Wow! Momo',
#   'Apna Dhaba',
#   'The Hubb',
#   'Bhooter Raja Dilo Bor',
#   'Fries Before Guys',
#   'Rooftop Top View',
#   'Subway',
#   'Ice Choco Cafe',
#   'Since 2016 Cafe',
#   'On My Way',
#   'Azad Hind Dhaba',
#   '7/12 Fried Ice Cream Parlour',
#   'Club 21',
#   'Eat Out',
#   'Banana Leaf',
#   'The Swig - Raajkutir, Swabhumi',
#   'The Burger Factory',
#   'So Southy',
#   'Floriana',
#   'Azad Hind Dhaba',
#   "Sam's Pub",
#   'KFC',
#   'KFC',
#   'KFC',
#   'Aminia',
#   'Hing',
#   'Fuel Resto Bar',
#   'Wow! Momo',
#   'Urban Kitchen & Bar',
#   'Wow! Momo',
#   'Wow! Momo',
#   'Wow! Momo',
#   'Bawarchi Fast Food'],
#  'cuisine': ['Finger Food, North Indian, Chinese',
#   'Fast Food, North Indian, Chinese',
#   'Chinese, Continental',
#   'Tibetan, Fast Food',
#   'Italian, Continental, Chinese',
#   'Finger Food',
#   'Fast Food',
#   'Finger Food, Chinese, Asian',
#   'Chinese, North Indian, Italian, Continental, Asian',
#   'Chinese, North Indian',
#   'Chinese, Seafood',
#   'Chinese',
#   'Continental, North Indian, Chinese',
#   'Chinese, North Indian, Continental',
#   'North Indian, Mughlai, Chinese, Biryani, Beverages, Desserts',
#   'Fast Food, Italian, Beverages',
#   'Tibetan, Fast Food',
#   'Tibetan, Fast Food',
#   'North Indian',
#   'Chinese, Continental, Fast Food',
#   'Bengali',
#   'Fast Food',
#   'South Indian, Fast Food',
#   'Fast Food',
#   'Chinese, Burger, Fast Food, Desserts, Beverages',
#   'Continental, Fast Food, Beverages',
#   'Chinese, North Indian, Fast Food, Beverages',
#   'North Indian, Chinese, Mughlai',
#   'Desserts',
#   'Chinese, Italian, Continental, Beverages',
#   'Chinese, North Indian',
#   'South Indian',
#   'Finger Food, North Indian, Beverages',
#   'Fast Food, North Indian, Chinese',
#   'North Indian, South Indian',
#   'Chinese, North Indian, Continental',
#   'North Indian, Chinese, Mughlai',
#   'Chinese, North Indian, Continental',
#   'Burger, Fast Food',
#   'Burger, Fast Food',
#   'Burger, Fast Food',
#   'Awadhi, North Indian',
#   'Chinese, North Indian, Seafood, Desserts',
#   'Finger Food',
#   'Tibetan, Fast Food',
#   'Finger Food',
#   'Tibetan, Fast Food',
#   'Tibetan, Fast Food',
#   'Tibetan, Fast Food',
#   'Fast Food'],
#  'location': ['City Centre 2, New Town,, Rajarhat, 24 Parganas North',
#   'Tangra, East Kolkata',
#   'Behala, South Kolkata',
#   'Santoshpur, South Kolkata',
#   'Salt Lake, East Kolkata',
#   'Forum Mall,, Elgin Road, South Kolkata',
#   'New Alipore, South Kolkata',
#   'The Peerless Inn,, Esplanade, Central Kolkata',
#   'Infinity Benchmark,, Salt Lake, East Kolkata',
#   'O2 Oxygen Hotel,, Kaikhali, 24 Parganas North',
#   'Southern Avenue, South Kolkata',
#   'Lake Town, East Kolkata',
#   'Kankurgachhi, East Kolkata',
#   'Jadavpur, South Kolkata',
#   'Behala, South Kolkata',
#   'Shakespeare Sarani, Central Kolkata',
#   'Howrah, Howrah',
#   'PS Magnum,, Kaikhali, 24 Parganas North',
#   'Bhawanipur, South Kolkata',
#   'Kalikapur, South Kolkata',
#   'Jadavpur, South Kolkata',
#   'Arihant Benchmark,, Topsia, East Kolkata',
#   'Elgin Road, South Kolkata',
#   'Tollygunge, South Kolkata',
#   'Tollygunge, South Kolkata',
#   'Salt Lake, East Kolkata',
#   'Rajarhat, 24 Parganas North',
#   'Bhawanipur, South Kolkata',
#   'Uniworld Downtown Mall,, New Town, 24 Parganas North',
#   'Meena Tower,, Rajarhat, 24 Parganas North',
#   'Topsia, East Kolkata',
#   'Ecospace Business Tower,, Rajarhat, 24 Parganas North',
#   'Kankurgachhi, East Kolkata',
#   'Park Street, Central Kolkata',
#   'New Town, 24 Parganas North',
#   'Park Street, Central Kolkata',
#   'Salt Lake, East Kolkata',
#   'Park Street, Central Kolkata',
#   'South City Mall,, Jadavpur, South Kolkata',
#   'Mani Square,, Kankurgachhi, East Kolkata',
#   'Baguiati, 24 Parganas North',
#   'Garia, South Kolkata',
#   'Salt Lake, East Kolkata',
#   'The Pride Hotel,, Rajarhat, 24 Parganas North',
#   'Rashbehari Avenue, South Kolkata',
#   'Holiday Inn Kolkata Airport,, Rajarhat, 24 Parganas North',
#   'Ultadanga, North Kolkata',
#   'Salt Lake, East Kolkata',
#   'Camac Street, Central Kolkata',
#   'Baghajatin, South Kolkata'],
#  'rating': [3.7,
#   3.7,
#   3.7,
#   3.7,
#   3.7,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.6,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5,
#   3.5],
#  'image_url': ['https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/m/n/p73503-15758713065dede34a6306c.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/w/v/p75101-16613301326305e2d47a360.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/v/u/p76234-15789942695e1d8a5d25f0c.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/i/w/p575-16814515386438ea1266f01.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/8/f/e/p88642-164164549461d985b66bad6.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/t/n/p3952-1614679392603e0d606bd8a.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/e/m/p20-166013236362f39c0b56a25.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/6/b/p/p6533-147392684157da56b9a386f.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/9/y/v/p9764-165846674262da31b6e839a.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/i/a/p12191-15528938035c8f476bcb61c.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/d/z/p16404-1496138706592d43d2879d3.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/j/y/p20622-1503470017599d21c1f4231.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/b/l/p20919-14957174425926d642e0226.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/s/q/p23467-148493809658825b70c9cbd.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/r/e/p26869-149882728659564a1611b11.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/e/m/p20-166013236362f39c0b56a25.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/i/w/p575-16814515386438ea1266f01.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/i/w/p575-16814515386438ea1266f01.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/v/u/p33638-150649306059cb428473f45.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/m/x/p33947-1501434567597e12c7a6dc0.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/g/o/p45021-164439518762037ab3489bf.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/z/c/p4567-1644241828620123a4d6b60.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/w/p/p52975-15506590425c6d2de298094.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/e/m/p20-166013236362f39c0b56a25.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/6/r/m/p62211-15713801015da95b85ca912.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/6/p/b/p64956-1645072637620dd0fd2be2a.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/6/i/b/p66622-165407507562972ec311a8f.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/k/h/p737-164078082261cc541678280.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/6/x/x/p6237-164164297161d97bdbc2fd8.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/6/p/j/p69549-15735568185dca925273cd0.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/o/a/p70763-15807943225e3901d277dec.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/p/i/p5213-164284881061ebe22a09292.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/l/y/p72532-16062955555fbe2003ab188.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/z/e/p75099-16613300726305e29819ccb.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/c/f/p75651-1613734107602fa0db3d522.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/d/j/p3844-1497265845593e76b537253.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/f/p/p4043-1495197646591ee7cee03b1.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/o/q/p5197-1651121715626a1e335255f.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/a/q/p7-15578302915cda9a939bee9.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/a/q/p7-15578302915cda9a939bee9.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/a/q/p7-15578302915cda9a939bee9.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/e/f/p12420-145457576956b310995d339.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/y/z/p13220-150713370859d5090c5f9b9.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/w/x/p13785-14672717185774ca265d388.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/i/w/p575-16814515386438ea1266f01.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/x/z/p36864-15663003745d5bd8d6bfb17.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/i/w/p575-16814515386438ea1266f01.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/i/w/p575-16814515386438ea1266f01.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/i/w/p575-16814515386438ea1266f01.jpg?tr=tr:n-medium',
#   'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/k/y/p1651-15708573305da16172c7896.jpg?tr=tr:n-medium']}

# %% [markdown]
# ## Write s python program to display list of respected former finance minister of India(i.e. Name , Term of office) from https://presidentofindia.nic.in/former-presidents.htm and make data frame.
#
# ### the web-link doesn't have any content
